# %%
import pandas as pd
import os

# Define dataset paths
hosp_path = "../data/mimic_demo/hosp/"
icu_path = "../data/mimic_demo/icu/"

# Load datasets
dfs = {}  # Dictionary to store DataFrames

# Function to load CSVs and display first rows
def load_and_preview_csvs(directory, dataset_type):
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            file_path = os.path.join(directory, file)
            try:
                df = pd.read_csv(file_path, low_memory=False)
                dfs[file.replace(".csv", "")] = df  # Store DataFrame
                print(f"\n📂 {dataset_type.upper()} - {file} loaded successfully! Shape: {df.shape}")
                print(df.head(2))  # Display first 2 rows
            except Exception as e:
                print(f"❌ Error loading {file}: {e}")

# Load & preview HOSP & ICU datasets
print("\n📂 Loading HOSP datasets...\n")
load_and_preview_csvs(hosp_path, "hosp")

print("\n📂 Loading ICU datasets...\n")
load_and_preview_csvs(icu_path, "icu")

print("\n✅ All datasets loaded!")
# Out:
# 📂 Loading HOSP datasets...
#
#
# 📂 HOSP - admissions.csv loaded successfully! Shape: (275, 16)
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    10004235  24181354  2196-02-24 14:38:00  2196-03-04 14:02:00       NaN
# 1    10009628  25926192  2153-09-17 17:08:00  2153-09-25 13:20:00       NaN
#
#   admission_type admit_provider_id      admission_location  \
# 0         URGENT            P03YMR  TRANSFER FROM HOSPITAL
# 1         URGENT            P41R5N  TRANSFER FROM HOSPITAL
#
#          discharge_location insurance language marital_status  \
# 0  SKILLED NURSING FACILITY  Medicaid  ENGLISH         SINGLE
# 1          HOME HEALTH CARE  Medicaid        ?        MARRIED
#
#                              race            edregtime            edouttime  \
# 0              BLACK/CAPE VERDEAN  2196-02-24 12:15:00  2196-02-24 17:07:00
# 1  HISPANIC/LATINO - PUERTO RICAN                  NaN                  NaN
#
#    hospital_expire_flag
# 0                     0
# 1                     0
#
# 📂 HOSP - diagnoses_icd.csv loaded successfully! Shape: (4506, 5)
#    subject_id   hadm_id  seq_num icd_code  icd_version
# 0    10035185  22580999        3     4139            9
# 1    10035185  22580999       10     V707            9
#
# 📂 HOSP - drgcodes.csv loaded successfully! Shape: (454, 7)
#    subject_id   hadm_id drg_type  drg_code                  description  \
# 0    10004235  22187210     HCFA       864                        FEVER
# 1    10026255  22059910     HCFA       180  RESPIRATORY NEOPLASMS W MCC
#
#    drg_severity  drg_mortality
# 0           NaN            NaN
# 1           NaN            NaN
#
# 📂 HOSP - d_hcpcs.csv loaded successfully! Shape: (89200, 4)
#     code  category                                   long_description  \
# 0  TD          NaN                                                 Rn
# 1  A0428       NaN  Ambulance service, basic life support, non-eme...
#
#   short_description
# 0                Rn
# 1               Bls
#
# 📂 HOSP - d_icd_diagnoses.csv loaded successfully! Shape: (109775, 3)
#   icd_code  icd_version                                         long_title
# 0     0090            9  Infectious colitis, enteritis, and gastroenter...
# 1    01160            9      Tuberculous pneumonia [any form], unspecified
#
# 📂 HOSP - d_icd_procedures.csv loaded successfully! Shape: (85257, 3)
#   icd_code  icd_version                                 long_title
# 0     0039            9            Other computer assisted surgery
# 1     0048            9  Insertion of four or more vascular stents
#
# 📂 HOSP - d_labitems.csv loaded successfully! Shape: (1622, 4)
#    itemid         label  fluid   category
# 0   50808  Free Calcium  Blood  Blood Gas
# 1   50826  Tidal Volume  Blood  Blood Gas
#
# 📂 HOSP - emar.csv loaded successfully! Shape: (35835, 12)
#    subject_id     hadm_id      emar_id  emar_seq       poe_id  pharmacy_id  \
# 0    10005909  20199380.0  10005909-74        74  10005909-97   96110427.0
# 1    10005909  20199380.0  10005909-79        79  10005909-97   96110427.0
#
#   enter_provider_id            charttime         medication event_txt  \
# 0               NaN  2144-10-31 05:56:00  Magnesium Sulfate       NaN
# 1               NaN  2144-10-31 08:00:00  Magnesium Sulfate       NaN
#
#           scheduletime            storetime
# 0  2144-10-31 05:56:00  2144-10-31 05:56:00
# 1  2144-10-31 08:00:00  2144-10-31 08:15:00
#
# 📂 HOSP - emar_detail.csv loaded successfully! Shape: (72018, 33)
#    subject_id        emar_id  emar_seq  parent_field_ordinal  \
# 0    10039708  10039708-1750      1750                   1.1
# 1    10015860   10015860-565       565                   1.1
#
#   administration_type  pharmacy_id barcode_type reason_for_no_barcode  \
# 0                 NaN   80400800.0          NaN                   NaN
# 1                 NaN   98178739.0          NaN                   NaN
#
#   complete_dose_not_given dose_due  ... infusion_rate_unit route  \
# 0                     NaN      NaN  ...                NaN   NaN
# 1                     NaN      NaN  ...                NaN   NaN
#
#   infusion_complete completion_interval  new_iv_bag_hung  \
# 0               NaN                 NaN              NaN
# 1               NaN                 NaN              NaN
#
#   continued_infusion_in_other_location restart_interval side site  \
# 0                                  NaN              NaN  NaN  NaN
# 1                                  NaN              NaN  NaN  NaN
#
#    non_formulary_visual_verification
# 0                                NaN
# 1                                NaN
#
# [2 rows x 33 columns]
#
# 📂 HOSP - hcpcsevents.csv loaded successfully! Shape: (61, 6)
#    subject_id   hadm_id   chartdate hcpcs_cd  seq_num short_description
# 0    10005348  29176490  2129-05-22    93454        1    Cardiovascular
# 1    10005348  29176490  2129-05-22    92921        2    Cardiovascular
#
# 📂 HOSP - labevents.csv loaded successfully! Shape: (107727, 16)
#    labevent_id  subject_id     hadm_id  specimen_id  itemid order_provider_id  \
# 0       172061    10014354  29600294.0      1808066   51277               NaN
# 1       172062    10014354  29600294.0      1808066   51279               NaN
#
#              charttime            storetime value  valuenum valueuom  \
# 0  2148-08-16 00:00:00  2148-08-16 01:30:00  15.4     15.40        %
# 1  2148-08-16 00:00:00  2148-08-16 01:30:00  3.35      3.35     m/uL
#
#    ref_range_lower  ref_range_upper      flag priority comments
# 0             10.5             15.5       NaN  ROUTINE      NaN
# 1              4.6              6.1  abnormal  ROUTINE      NaN
#
# 📂 HOSP - microbiologyevents.csv loaded successfully! Shape: (2899, 25)
#    microevent_id  subject_id     hadm_id  micro_specimen_id order_provider_id  \
# 0             36    10000032  25742920.0            7814634               NaN
# 1             15    10000032  22595853.0            5717063               NaN
#
#              chartdate            charttime  spec_itemid spec_type_desc  \
# 0  2180-08-06 00:00:00  2180-08-06 20:35:00        70070           SWAB
# 1  2180-05-07 00:00:00  2180-05-07 00:19:00        70070           SWAB
#
#    test_seq  ... org_name isolate_num  quantity ab_itemid  ab_name  \
# 0         1  ...      NaN         NaN       NaN       NaN      NaN
# 1         1  ...      NaN         NaN       NaN       NaN      NaN
#
#   dilution_text  dilution_comparison  dilution_value  interpretation  \
# 0           NaN                  NaN             NaN             NaN
# 1           NaN                  NaN             NaN             NaN
#
#              comments
# 0  No VRE isolated.
# 1  No VRE isolated.
#
# [2 rows x 25 columns]
#
# 📂 HOSP - omr.csv loaded successfully! Shape: (2964, 5)
#    subject_id   chartdate  seq_num      result_name result_value
# 0    10011398  2146-12-01        1  Height (Inches)           63
# 1    10011398  2147-01-22        1     Weight (Lbs)          127
#
# 📂 HOSP - patients.csv loaded successfully! Shape: (100, 6)
#    subject_id gender  anchor_age  anchor_year anchor_year_group         dod
# 0    10014729      F          21         2125       2011 - 2013         NaN
# 1    10003400      F          72         2134       2011 - 2013  2137-09-02
#
# 📂 HOSP - pharmacy.csv loaded successfully! Shape: (15306, 27)
#    subject_id   hadm_id  pharmacy_id poe_id            starttime stoptime  \
# 0    10027602  28166872     24340150    NaN  2201-10-30 12:00:00      NaN
# 1    10027602  28166872     14435820    NaN  2201-10-30 12:00:00      NaN
#
#   medication              proc_type                            status  \
# 0  Midazolam  Miscellaneous Charges  Inactive (Due to a change order)
# 1  Midazolam  Miscellaneous Charges  Inactive (Due to a change order)
#
#              entertime  ... basal_rate one_hr_max doses_per_24_hrs duration  \
# 0  2201-10-30 12:32:11  ...        NaN        NaN              NaN      NaN
# 1  2201-10-30 12:54:34  ...        NaN        NaN              NaN      NaN
#
#   duration_interval expiration_value  expiration_unit  expirationdate  \
# 0               NaN              NaN              NaN             NaN
# 1               NaN              NaN              NaN             NaN
#
#    dispensation  fill_quantity
# 0           NaN            NaN
# 1           NaN            NaN
#
# [2 rows x 27 columns]
#
# 📂 HOSP - poe.csv loaded successfully! Shape: (45154, 12)
#          poe_id  poe_seq  subject_id   hadm_id            ordertime  \
# 0  10002930-456      456    10002930  20282368  2201-03-23 19:14:33
# 1  10002930-454      454    10002930  20282368  2201-03-23 19:14:33
#
#      order_type      order_subtype transaction_type discontinue_of_poe_id  \
# 0  General Care              Other              New                   NaN
# 1  General Care  Vitals/Monitoring              New                   NaN
#
#   discontinued_by_poe_id order_provider_id order_status
# 0                    NaN            P04TDP     Inactive
# 1                    NaN            P04TDP     Inactive
#
# 📂 HOSP - poe_detail.csv loaded successfully! Shape: (3795, 5)
#          poe_id  poe_seq  subject_id   field_name field_value
# 0   10011398-23       23    10011398     Admit to     Surgery
# 1  10011398-103      103    10011398  Transfer to     Surgery
#
# 📂 HOSP - prescriptions.csv loaded successfully! Shape: (18087, 21)
#    subject_id   hadm_id  pharmacy_id poe_id  poe_seq order_provider_id  \
# 0    10027602  28166872     27168639    NaN      NaN               NaN
# 1    10027602  28166872     40720238    NaN      NaN               NaN
#
#              starttime stoptime drug_type              drug  ...  gsn ndc  \
# 0  2201-10-30 12:00:00      NaN      MAIN  Fentanyl Citrate  ...  NaN NaN
# 1  2201-10-30 12:00:00      NaN      MAIN  Fentanyl Citrate  ...  NaN NaN
#
#    prod_strength form_rx dose_val_rx dose_unit_rx form_val_disp  \
# 0            NaN     NaN         NaN          NaN           NaN
# 1            NaN     NaN         NaN          NaN           NaN
#
#   form_unit_disp doses_per_24_hrs  route
# 0            NaN              NaN    NaN
# 1            NaN              NaN    NaN
#
# [2 rows x 21 columns]
#
# 📂 HOSP - procedures_icd.csv loaded successfully! Shape: (722, 6)
#    subject_id   hadm_id  seq_num   chartdate icd_code  icd_version
# 0    10011398  27505812        3  2146-12-15     3961            9
# 1    10011398  27505812        2  2146-12-15     3615            9
#
# 📂 HOSP - provider.csv loaded successfully! Shape: (40508, 1)
#   provider_id
# 0      P003F3
# 1      P005JG
#
# 📂 HOSP - services.csv loaded successfully! Shape: (319, 5)
#    subject_id   hadm_id         transfertime prev_service curr_service
# 0    10001725  25563031  2110-04-11 15:09:36          NaN          GYN
# 1    10019003  28003918  2148-12-21 03:32:53          NaN          GYN
#
# 📂 HOSP - transfers.csv loaded successfully! Shape: (1190, 7)
#    subject_id     hadm_id  transfer_id  eventtype careunit  \
# 0    10009049  22995465.0     30030230  discharge      NaN
# 1    10025612  23403708.0     32533329  discharge      NaN
#
#                 intime outtime
# 0  2174-05-31 14:21:47     NaN
# 1  2125-10-03 12:25:27     NaN
#
# 📂 Loading ICU datasets...
#
#
# 📂 ICU - caregiver.csv loaded successfully! Shape: (15468, 1)
#    caregiver_id
# 0           444
# 1          1016
#
# 📂 ICU - chartevents.csv loaded successfully! Shape: (668862, 11)
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10005817  20626031  32604416        6770.0  2132-12-16 00:00:00
# 1    10005817  20626031  32604416        6770.0  2132-12-16 00:00:00
#
#              storetime  itemid value  valuenum valueuom  warning
# 0  2132-12-15 23:45:00  225054   On        NaN      NaN      0.0
# 1  2132-12-15 23:43:00  223769   100     100.0        %      0.0
#
# 📂 ICU - datetimeevents.csv loaded successfully! Shape: (15280, 10)
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10002428  23473524  35479615         29441  2156-05-15 10:50:00
# 1    10002428  23473524  35479615         29441  2156-05-15 10:50:00
#
#              storetime  itemid                value valueuom  warning
# 0  2156-05-15 10:50:00  225343  2156-05-11 00:00:00     Date        0
# 1  2156-05-15 10:50:00  225348  2156-05-11 00:00:00     Date        0
#
# 📂 ICU - d_items.csv loaded successfully! Shape: (4014, 9)
#    itemid   label abbreviation      linksto category unitname param_type  \
# 0  226228  Gender       Gender  chartevents      ADT      NaN       Text
# 1  226545    Race         Race  chartevents      ADT      NaN       Text
#
#    lownormalvalue  highnormalvalue
# 0             NaN              NaN
# 1             NaN              NaN
#
# 📂 ICU - icustays.csv loaded successfully! Shape: (140, 8)
#    subject_id   hadm_id   stay_id  \
# 0    10018328  23786647  31269608
# 1    10020187  24104168  37509585
#
#                                     first_careunit   last_careunit  \
# 0                                   Neuro Stepdown  Neuro Stepdown
# 1  Neuro Surgical Intensive Care Unit (Neuro SICU)  Neuro Stepdown
#
#                 intime              outtime       los
# 0  2154-04-24 23:03:44  2154-05-02 15:55:21  7.702512
# 1  2169-01-15 04:56:00  2169-01-20 15:47:50  5.452662
#
# 📂 ICU - ingredientevents.csv loaded successfully! Shape: (25728, 17)
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10005817  20626031  32604416          4793  2132-12-17 05:00:00
# 1    10005817  20626031  32604416          4793  2132-12-17 05:00:00
#
#                endtime            storetime  itemid     amount amountuom  \
# 0  2132-12-17 06:00:00  2132-12-17 06:01:00  227074  49.999999        ml
# 1  2132-12-17 06:00:00  2132-12-17 06:01:00  220490  49.999999        ml
#
#    rate  rateuom  orderid  linkorderid statusdescription  originalamount  \
# 0  50.0  mL/hour  7330951      7330951   FinishedRunning               0
# 1  50.0  mL/hour  7330951      7330951   FinishedRunning               0
#
#    originalrate
# 0          50.0
# 1          50.0
#
# 📂 ICU - inputevents.csv loaded successfully! Shape: (20404, 26)
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10005817  20626031  32604416          4793  2132-12-16 19:50:00
# 1    10005817  20626031  32604416         92805  2132-12-15 20:15:00
#
#                endtime            storetime  itemid  amount amountuom  ...  \
# 0  2132-12-16 19:51:00  2132-12-16 19:50:00  225798     1.0      dose  ...
# 1  2132-12-15 20:16:00  2132-12-15 20:11:00  225798     1.0      dose  ...
#
#    ordercomponenttypedescription ordercategorydescription  patientweight  \
# 0           Main order parameter                Drug Push           91.0
# 1           Main order parameter                Drug Push           91.0
#
#    totalamount totalamountuom isopenbag continueinnextdept statusdescription  \
# 0        500.0             ml         0                  0   FinishedRunning
# 1        500.0             ml         0                  0   FinishedRunning
#
#    originalamount  originalrate
# 0             1.0           1.0
# 1             1.0           1.0
#
# [2 rows x 26 columns]
#
# 📂 ICU - outputevents.csv loaded successfully! Shape: (9362, 9)
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10002428  23473524  35479615         29441  2156-05-15 18:00:00
# 1    10002428  23473524  35479615         29441  2156-05-15 12:00:00
#
#              storetime  itemid  value valueuom
# 0  2156-05-15 17:42:00  226583    600       ml
# 1  2156-05-15 12:08:00  226559     60       ml
#
# 📂 ICU - procedureevents.csv loaded successfully! Shape: (1468, 22)
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10027445  26275841  34499716       10712.0  2142-07-31 01:54:00
# 1    10027445  26275841  34499716       80518.0  2142-07-31 08:18:00
#
#                endtime            storetime  itemid   value valueuom  ...  \
# 0  2142-08-02 10:44:00  2142-08-02 10:44:00  225792  3410.0      min  ...
# 1  2142-08-03 15:10:00  2142-08-03 15:23:00  224263  4732.0      min  ...
#
#   orderid linkorderid  ordercategoryname  ordercategorydescription  \
# 0  532221      532221        Ventilation         ContinuousProcess
# 1  401769      401769     Invasive Lines         ContinuousProcess
#
#   patientweight isopenbag  continueinnextdept  statusdescription  \
# 0         103.0         1                   0    FinishedRunning
# 1         103.0         1                   0    FinishedRunning
#
#    ORIGINALAMOUNT ORIGINALRATE
# 0          3410.0            1
# 1          4732.0            1
#
# [2 rows x 22 columns]
#
# ✅ All datasets loaded!

# %%
# Function to summarize each DataFrame
def summarize_dataframe(name, df):
    print(f"\n📂 **{name.upper()}** - Shape: {df.shape}")
    
    # Data types
    print("\n📝 Data Types:")
    print(df.dtypes)
    
    # Missing values
    print("\n🔍 Missing Values:")
    missing = df.isnull().sum()
    print(missing[missing > 0])
    
    # Unique values (only for small columns)
    print("\n🔹 Unique Values (first 5 columns):")
    for col in df.columns[:5]:
        print(f"  {col}: {df[col].nunique()} unique values")
    
    print("="*50)

# Apply function to all datasets
for name, df in dfs.items():
    summarize_dataframe(name, df)

print("\n✅ Data profiling completed!")
# Out:
# 📂 **ADMISSIONS** - Shape: (275, 16)
#
# 📝 Data Types:
# subject_id               int64
# hadm_id                  int64
# admittime               object
# dischtime               object
# deathtime               object
# admission_type          object
# admit_provider_id       object
# admission_location      object
# discharge_location      object
# insurance               object
# language                object
# marital_status          object
# race                    object
# edregtime               object
# edouttime               object
# hospital_expire_flag     int64
# dtype: object
#
# 🔍 Missing Values:
# deathtime             260
# discharge_location     42
# marital_status         12
# edregtime              93
# edouttime              93
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 275 unique values
#   admittime: 275 unique values
#   dischtime: 275 unique values
#   deathtime: 15 unique values
# ==================================================
#
# 📂 **DIAGNOSES_ICD** - Shape: (4506, 5)
#
# 📝 Data Types:
# subject_id      int64
# hadm_id         int64
# seq_num         int64
# icd_code       object
# icd_version     int64
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 275 unique values
#   seq_num: 39 unique values
#   icd_code: 1472 unique values
#   icd_version: 2 unique values
# ==================================================
#
# 📂 **DRGCODES** - Shape: (454, 7)
#
# 📝 Data Types:
# subject_id         int64
# hadm_id            int64
# drg_type          object
# drg_code           int64
# description       object
# drg_severity     float64
# drg_mortality    float64
# dtype: object
#
# 🔍 Missing Values:
# drg_severity     233
# drg_mortality    233
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 233 unique values
#   drg_type: 2 unique values
#   drg_code: 240 unique values
#   description: 259 unique values
# ==================================================
#
# 📂 **D_HCPCS** - Shape: (89200, 4)
#
# 📝 Data Types:
# code                  object
# category             float64
# long_description      object
# short_description     object
# dtype: object
#
# 🔍 Missing Values:
# category             6844
# long_description    82400
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   code: 89200 unique values
#   category: 3 unique values
#   long_description: 6674 unique values
#   short_description: 6811 unique values
# ==================================================
#
# 📂 **D_ICD_DIAGNOSES** - Shape: (109775, 3)
#
# 📝 Data Types:
# icd_code       object
# icd_version     int64
# long_title     object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   icd_code: 109282 unique values
#   icd_version: 2 unique values
#   long_title: 106327 unique values
# ==================================================
#
# 📂 **D_ICD_PROCEDURES** - Shape: (85257, 3)
#
# 📝 Data Types:
# icd_code       object
# icd_version     int64
# long_title     object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   icd_code: 85251 unique values
#   icd_version: 2 unique values
#   long_title: 85256 unique values
# ==================================================
#
# 📂 **D_LABITEMS** - Shape: (1622, 4)
#
# 📝 Data Types:
# itemid       int64
# label       object
# fluid       object
# category    object
# dtype: object
#
# 🔍 Missing Values:
# label    3
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   itemid: 1622 unique values
#   label: 1170 unique values
#   fluid: 12 unique values
#   category: 3 unique values
# ==================================================
#
# 📂 **EMAR** - Shape: (35835, 12)
#
# 📝 Data Types:
# subject_id             int64
# hadm_id              float64
# emar_id               object
# emar_seq               int64
# poe_id                object
# pharmacy_id          float64
# enter_provider_id     object
# charttime             object
# medication            object
# event_txt             object
# scheduletime          object
# storetime             object
# dtype: object
#
# 🔍 Missing Values:
# hadm_id               1006
# pharmacy_id           6463
# enter_provider_id    32895
# medication            1576
# event_txt              311
# scheduletime            13
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 65 unique values
#   hadm_id: 181 unique values
#   emar_id: 35835 unique values
#   emar_seq: 3918 unique values
#   poe_id: 7966 unique values
# ==================================================
#
# 📂 **EMAR_DETAIL** - Shape: (72018, 33)
#
# 📝 Data Types:
# subject_id                                int64
# emar_id                                  object
# emar_seq                                  int64
# parent_field_ordinal                    float64
# administration_type                      object
# pharmacy_id                             float64
# barcode_type                             object
# reason_for_no_barcode                    object
# complete_dose_not_given                  object
# dose_due                                 object
# dose_due_unit                            object
# dose_given                               object
# dose_given_unit                          object
# will_remainder_of_dose_be_given          object
# product_amount_given                    float64
# product_unit                             object
# product_code                             object
# product_description                      object
# product_description_other                object
# prior_infusion_rate                     float64
# infusion_rate                           float64
# infusion_rate_adjustment                 object
# infusion_rate_adjustment_amount         float64
# infusion_rate_unit                       object
# route                                    object
# infusion_complete                        object
# completion_interval                      object
# new_iv_bag_hung                          object
# continued_infusion_in_other_location     object
# restart_interval                         object
# side                                     object
# site                                     object
# non_formulary_visual_verification        object
# dtype: object
#
# 🔍 Missing Values:
# parent_field_ordinal                    35835
# administration_type                     36190
# pharmacy_id                             37230
# barcode_type                            37280
# reason_for_no_barcode                   70615
# complete_dose_not_given                 57248
# dose_due                                38200
# dose_due_unit                           36665
# dose_given                              39363
# dose_given_unit                         38545
# will_remainder_of_dose_be_given         53366
# product_amount_given                    41630
# product_unit                            40789
# product_code                            37771
# product_description                     43184
# product_description_other               68946
# prior_infusion_rate                     70578
# infusion_rate                           70211
# infusion_rate_adjustment                69234
# infusion_rate_adjustment_amount         71942
# infusion_rate_unit                      69103
# route                                   61407
# infusion_complete                       71627
# completion_interval                     71674
# new_iv_bag_hung                         71558
# continued_infusion_in_other_location    72004
# restart_interval                        71887
# side                                    71839
# site                                    71839
# non_formulary_visual_verification       71910
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 65 unique values
#   emar_id: 35835 unique values
#   emar_seq: 3918 unique values
#   parent_field_ordinal: 12 unique values
#   administration_type: 20 unique values
# ==================================================
#
# 📂 **HCPCSEVENTS** - Shape: (61, 6)
#
# 📝 Data Types:
# subject_id            int64
# hadm_id               int64
# chartdate            object
# hcpcs_cd             object
# seq_num               int64
# short_description    object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 18 unique values
#   hadm_id: 41 unique values
#   chartdate: 42 unique values
#   hcpcs_cd: 19 unique values
#   seq_num: 4 unique values
# ==================================================
#
# 📂 **LABEVENTS** - Shape: (107727, 16)
#
# 📝 Data Types:
# labevent_id            int64
# subject_id             int64
# hadm_id              float64
# specimen_id            int64
# itemid                 int64
# order_provider_id     object
# charttime             object
# storetime             object
# value                 object
# valuenum             float64
# valueuom              object
# ref_range_lower      float64
# ref_range_upper      float64
# flag                  object
# priority              object
# comments              object
# dtype: object
#
# 🔍 Missing Values:
# hadm_id              28420
# order_provider_id    90897
# storetime              992
# value                 9588
# valuenum             12481
# valueuom             16203
# ref_range_lower      18728
# ref_range_upper      18728
# flag                 67452
# priority              9329
# comments             89273
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   labevent_id: 107727 unique values
#   subject_id: 100 unique values
#   hadm_id: 252 unique values
#   specimen_id: 11122 unique values
#   itemid: 498 unique values
# ==================================================
#
# 📂 **MICROBIOLOGYEVENTS** - Shape: (2899, 25)
#
# 📝 Data Types:
# microevent_id            int64
# subject_id               int64
# hadm_id                float64
# micro_specimen_id        int64
# order_provider_id       object
# chartdate               object
# charttime               object
# spec_itemid              int64
# spec_type_desc          object
# test_seq                 int64
# storedate               object
# storetime               object
# test_itemid              int64
# test_name               object
# org_itemid             float64
# org_name                object
# isolate_num            float64
# quantity               float64
# ab_itemid              float64
# ab_name                 object
# dilution_text           object
# dilution_comparison     object
# dilution_value         float64
# interpretation          object
# comments                object
# dtype: object
#
# 🔍 Missing Values:
# hadm_id                 971
# order_provider_id      2596
# charttime               183
# storedate                16
# storetime                16
# org_itemid             1641
# org_name               1641
# isolate_num            1641
# quantity               2899
# ab_itemid              1863
# ab_name                1863
# dilution_text          1900
# dilution_comparison    1901
# dilution_value         1901
# interpretation         1863
# comments                811
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   microevent_id: 2899 unique values
#   subject_id: 97 unique values
#   hadm_id: 171 unique values
#   micro_specimen_id: 1336 unique values
#   order_provider_id: 44 unique values
# ==================================================
#
# 📂 **OMR** - Shape: (2964, 5)
#
# 📝 Data Types:
# subject_id       int64
# chartdate       object
# seq_num          int64
# result_name     object
# result_value    object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 79 unique values
#   chartdate: 945 unique values
#   seq_num: 27 unique values
#   result_name: 8 unique values
#   result_value: 1427 unique values
# ==================================================
#
# 📂 **PATIENTS** - Shape: (100, 6)
#
# 📝 Data Types:
# subject_id            int64
# gender               object
# anchor_age            int64
# anchor_year           int64
# anchor_year_group    object
# dod                  object
# dtype: object
#
# 🔍 Missing Values:
# dod    69
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   gender: 2 unique values
#   anchor_age: 50 unique values
#   anchor_year: 62 unique values
#   anchor_year_group: 2 unique values
# ==================================================
#
# 📂 **PHARMACY** - Shape: (15306, 27)
#
# 📝 Data Types:
# subject_id             int64
# hadm_id                int64
# pharmacy_id            int64
# poe_id                object
# starttime             object
# stoptime              object
# medication            object
# proc_type             object
# status                object
# entertime             object
# verifiedtime          object
# route                 object
# frequency             object
# disp_sched            object
# infusion_type         object
# sliding_scale         object
# lockout_interval     float64
# basal_rate           float64
# one_hr_max           float64
# doses_per_24_hrs     float64
# duration             float64
# duration_interval     object
# expiration_value     float64
# expiration_unit       object
# expirationdate       float64
# dispensation          object
# fill_quantity        float64
# dtype: object
#
# 🔍 Missing Values:
# poe_id                  86
# stoptime                81
# medication            1013
# verifiedtime             6
# route                   87
# frequency               87
# disp_sched            6397
# infusion_type        14272
# sliding_scale        13266
# lockout_interval     15054
# basal_rate           15053
# one_hr_max           15246
# doses_per_24_hrs      6040
# duration             11297
# duration_interval       87
# expiration_value      2292
# expiration_unit        102
# expirationdate       15306
# dispensation            90
# fill_quantity        15306
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 250 unique values
#   pharmacy_id: 15306 unique values
#   poe_id: 13470 unique values
#   starttime: 6856 unique values
# ==================================================
#
# 📂 **POE** - Shape: (45154, 12)
#
# 📝 Data Types:
# poe_id                    object
# poe_seq                    int64
# subject_id                 int64
# hadm_id                    int64
# ordertime                 object
# order_type                object
# order_subtype             object
# transaction_type          object
# discontinue_of_poe_id     object
# discontinued_by_poe_id    object
# order_provider_id         object
# order_status              object
# dtype: object
#
# 🔍 Missing Values:
# order_subtype             28795
# discontinue_of_poe_id     34644
# discontinued_by_poe_id    34695
# order_provider_id           792
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   poe_id: 45154 unique values
#   poe_seq: 3194 unique values
#   subject_id: 100 unique values
#   hadm_id: 272 unique values
#   ordertime: 21046 unique values
# ==================================================
#
# 📂 **POE_DETAIL** - Shape: (3795, 5)
#
# 📝 Data Types:
# poe_id         object
# poe_seq         int64
# subject_id      int64
# field_name     object
# field_value    object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   poe_id: 2691 unique values
#   poe_seq: 1247 unique values
#   subject_id: 100 unique values
#   field_name: 11 unique values
#   field_value: 59 unique values
# ==================================================
#
# 📂 **PRESCRIPTIONS** - Shape: (18087, 21)
#
# 📝 Data Types:
# subject_id             int64
# hadm_id                int64
# pharmacy_id            int64
# poe_id                object
# poe_seq              float64
# order_provider_id     object
# starttime             object
# stoptime              object
# drug_type             object
# drug                  object
# formulary_drug_cd     object
# gsn                   object
# ndc                  float64
# prod_strength         object
# form_rx               object
# dose_val_rx           object
# dose_unit_rx          object
# form_val_disp         object
# form_unit_disp        object
# doses_per_24_hrs     float64
# route                 object
# dtype: object
#
# 🔍 Missing Values:
# poe_id                 118
# poe_seq                118
# order_provider_id       94
# stoptime                14
# formulary_drug_cd       12
# gsn                   2519
# ndc                     21
# prod_strength            9
# form_rx              18075
# dose_val_rx              9
# dose_unit_rx             9
# form_val_disp            9
# form_unit_disp           9
# doses_per_24_hrs      7383
# route                    6
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 250 unique values
#   pharmacy_id: 15225 unique values
#   poe_id: 13389 unique values
#   poe_seq: 2336 unique values
# ==================================================
#
# 📂 **PROCEDURES_ICD** - Shape: (722, 6)
#
# 📝 Data Types:
# subject_id      int64
# hadm_id         int64
# seq_num         int64
# chartdate      object
# icd_code       object
# icd_version     int64
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 92 unique values
#   hadm_id: 187 unique values
#   seq_num: 23 unique values
#   chartdate: 385 unique values
#   icd_code: 352 unique values
# ==================================================
#
# 📂 **PROVIDER** - Shape: (40508, 1)
#
# 📝 Data Types:
# provider_id    object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   provider_id: 40508 unique values
# ==================================================
#
# 📂 **SERVICES** - Shape: (319, 5)
#
# 📝 Data Types:
# subject_id       int64
# hadm_id          int64
# transfertime    object
# prev_service    object
# curr_service    object
# dtype: object
#
# 🔍 Missing Values:
# prev_service    275
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 275 unique values
#   transfertime: 319 unique values
#   prev_service: 10 unique values
#   curr_service: 13 unique values
# ==================================================
#
# 📂 **TRANSFERS** - Shape: (1190, 7)
#
# 📝 Data Types:
# subject_id       int64
# hadm_id        float64
# transfer_id      int64
# eventtype       object
# careunit        object
# intime          object
# outtime         object
# dtype: object
#
# 🔍 Missing Values:
# hadm_id      54
# careunit    275
# outtime     275
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 275 unique values
#   transfer_id: 1190 unique values
#   eventtype: 4 unique values
#   careunit: 31 unique values
# ==================================================
#
# 📂 **CAREGIVER** - Shape: (15468, 1)
#
# 📝 Data Types:
# caregiver_id    int64
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   caregiver_id: 15468 unique values
# ==================================================
#
# 📂 **CHARTEVENTS** - Shape: (668862, 11)
#
# 📝 Data Types:
# subject_id        int64
# hadm_id           int64
# stay_id           int64
# caregiver_id    float64
# charttime        object
# storetime        object
# itemid            int64
# value            object
# valuenum        float64
# valueuom         object
# warning         float64
# dtype: object
#
# 🔍 Missing Values:
# caregiver_id     24240
# storetime         1159
# value            20730
# valuenum        411388
# valueuom        506291
# warning           1159
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 128 unique values
#   stay_id: 140 unique values
#   caregiver_id: 692 unique values
#   charttime: 36303 unique values
# ==================================================
#
# 📂 **DATETIMEEVENTS** - Shape: (15280, 10)
#
# 📝 Data Types:
# subject_id       int64
# hadm_id          int64
# stay_id          int64
# caregiver_id     int64
# charttime       object
# storetime       object
# itemid           int64
# value           object
# valueuom        object
# warning          int64
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 127 unique values
#   stay_id: 138 unique values
#   caregiver_id: 381 unique values
#   charttime: 4152 unique values
# ==================================================
#
# 📂 **D_ITEMS** - Shape: (4014, 9)
#
# 📝 Data Types:
# itemid               int64
# label               object
# abbreviation        object
# linksto             object
# category            object
# unitname            object
# param_type          object
# lownormalvalue     float64
# highnormalvalue    float64
# dtype: object
#
# 🔍 Missing Values:
# unitname           2906
# lownormalvalue     3995
# highnormalvalue    3992
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   itemid: 4014 unique values
#   label: 3888 unique values
#   abbreviation: 3895 unique values
#   linksto: 6 unique values
#   category: 81 unique values
# ==================================================
#
# 📂 **ICUSTAYS** - Shape: (140, 8)
#
# 📝 Data Types:
# subject_id          int64
# hadm_id             int64
# stay_id             int64
# first_careunit     object
# last_careunit      object
# intime             object
# outtime            object
# los               float64
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 128 unique values
#   stay_id: 140 unique values
#   first_careunit: 9 unique values
#   last_careunit: 9 unique values
# ==================================================
#
# 📂 **INGREDIENTEVENTS** - Shape: (25728, 17)
#
# 📝 Data Types:
# subject_id             int64
# hadm_id                int64
# stay_id                int64
# caregiver_id           int64
# starttime             object
# endtime               object
# storetime             object
# itemid                 int64
# amount               float64
# amountuom             object
# rate                 float64
# rateuom               object
# orderid                int64
# linkorderid            int64
# statusdescription     object
# originalamount         int64
# originalrate         float64
# dtype: object
#
# 🔍 Missing Values:
# rate       9085
# rateuom    9085
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 99 unique values
#   hadm_id: 127 unique values
#   stay_id: 138 unique values
#   caregiver_id: 391 unique values
#   starttime: 9565 unique values
# ==================================================
#
# 📂 **INPUTEVENTS** - Shape: (20404, 26)
#
# 📝 Data Types:
# subject_id                         int64
# hadm_id                            int64
# stay_id                            int64
# caregiver_id                       int64
# starttime                         object
# endtime                           object
# storetime                         object
# itemid                             int64
# amount                           float64
# amountuom                         object
# rate                             float64
# rateuom                           object
# orderid                            int64
# linkorderid                        int64
# ordercategoryname                 object
# secondaryordercategoryname        object
# ordercomponenttypedescription     object
# ordercategorydescription          object
# patientweight                    float64
# totalamount                      float64
# totalamountuom                    object
# isopenbag                          int64
# continueinnextdept                 int64
# statusdescription                 object
# originalamount                   float64
# originalrate                     float64
# dtype: object
#
# 🔍 Missing Values:
# rate                          9366
# rateuom                       9366
# secondaryordercategoryname    6260
# totalamount                   3314
# totalamountuom                3312
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 99 unique values
#   hadm_id: 127 unique values
#   stay_id: 138 unique values
#   caregiver_id: 397 unique values
#   starttime: 11793 unique values
# ==================================================
#
# 📂 **OUTPUTEVENTS** - Shape: (9362, 9)
#
# 📝 Data Types:
# subject_id       int64
# hadm_id          int64
# stay_id          int64
# caregiver_id     int64
# charttime       object
# storetime       object
# itemid           int64
# value            int64
# valueuom        object
# dtype: object
#
# 🔍 Missing Values:
# Series([], dtype: int64)
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 126 unique values
#   stay_id: 137 unique values
#   caregiver_id: 435 unique values
#   charttime: 7898 unique values
# ==================================================
#
# 📂 **PROCEDUREEVENTS** - Shape: (1468, 22)
#
# 📝 Data Types:
# subject_id                    int64
# hadm_id                       int64
# stay_id                       int64
# caregiver_id                float64
# starttime                    object
# endtime                      object
# storetime                    object
# itemid                        int64
# value                       float64
# valueuom                     object
# location                     object
# locationcategory             object
# orderid                       int64
# linkorderid                   int64
# ordercategoryname            object
# ordercategorydescription     object
# patientweight               float64
# isopenbag                     int64
# continueinnextdept            int64
# statusdescription            object
# ORIGINALAMOUNT              float64
# ORIGINALRATE                  int64
# dtype: object
#
# 🔍 Missing Values:
# caregiver_id         242
# valueuom             771
# location            1115
# locationcategory    1115
# dtype: int64
#
# 🔹 Unique Values (first 5 columns):
#   subject_id: 100 unique values
#   hadm_id: 128 unique values
#   stay_id: 138 unique values
#   caregiver_id: 297 unique values
#   starttime: 1241 unique values
# ==================================================
#
# ✅ Data profiling completed!

# %%
# View column names to confirm expected fields exist
print(dfs['icustays'].columns)
print(dfs['admissions'].columns)
print(dfs['patients'].columns)
# Out:
# Patients who received vasopressors: 0
